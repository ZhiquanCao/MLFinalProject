# %%
import numpy as np
import matplotlib
import pandas as pd
import matplotlib.pyplot as plt

# %%
# data
accuracy_scores = {}
accuracy_scores["linear_1_100"] = 0.8960274644433546
accuracy_scores["linear_1_500"] = 0.9529180971064247
accuracy_scores["linear_1_1000"] = 0.9691025012260912
accuracy_scores["linear_10_100"] = 0.8960274644433546
accuracy_scores["linear_10_500"] = 0.9529180971064247
accuracy_scores["linear_10_1000"] = 0.9691025012260912
accuracy_scores["linear_100_100"] = 0.8960274644433546
accuracy_scores["linear_100_500"] = 0.9529180971064247
accuracy_scores["linear_100_1000"] = 0.9691025012260912
accuracy_scores["rbf_1_100"] = 0.9637076998528691
accuracy_scores["rbf_1_500"] = 0.9661598822952427
accuracy_scores["rbf_1_1000"] = 0.9661598822952427
accuracy_scores["rbf_10_100"] = 0.9892103972535556
accuracy_scores["rbf_10_500"] = 0.988719960765081
accuracy_scores["rbf_10_1000"] = 0.988719960765081
accuracy_scores["rbf_100_100"] = 0.9897008337420304
accuracy_scores["rbf_100_500"] = 0.988719960765081
accuracy_scores["rbf_100_1000"] = 0.988719960765081
accuracy_scores["sigmoid_1_100"] = 0.5522314860225601
accuracy_scores["sigmoid_1_500"] = 0.7425208435507602
accuracy_scores["sigmoid_1_1000"] = 0.7415399705738107
accuracy_scores["sigmoid_10_100"] = 0.5434036292300147
accuracy_scores["sigmoid_10_500"] = 0.6758214811181952
accuracy_scores["sigmoid_10_1000"] = 0.6787641000490436
accuracy_scores["sigmoid_100_100"] = 0.5453653751839137
accuracy_scores["sigmoid_100_500"] = 0.6738597351642962
accuracy_scores["sigmoid_100_1000"] = 0.6728788621873467
accuracy_scores["poly_1_100_1"] = 0.8700343305541932
accuracy_scores["poly_1_500_1"] = 0.916135360470819
accuracy_scores["poly_1_1000_1"] = 0.9176066699362433
accuracy_scores["poly_10_100_1"] = 0.9033840117704757
accuracy_scores["poly_10_500_1"] = 0.9421284943599804
accuracy_scores["poly_10_1000_1"] = 0.9391858754291319
accuracy_scores["poly_100_100_1"] = 0.8960274644433546
accuracy_scores["poly_100_500_1"] = 0.9548798430603237
accuracy_scores["poly_100_1000_1"] = 0.9700833742030407
accuracy_scores["poly_1_100_2"] = 0.9249632172633644
accuracy_scores["poly_1_500_2"] = 0.9622363903874448
accuracy_scores["poly_1_1000_2"] = 0.9627268268759196
accuracy_scores["poly_10_100_2"] = 0.9813634134379597
accuracy_scores["poly_10_500_2"] = 0.9872486512996567
accuracy_scores["poly_10_1000_2"] = 0.9872486512996567
accuracy_scores["poly_100_100_2"] = 0.982834722903384
accuracy_scores["poly_100_500_2"] = 0.9872486512996567
accuracy_scores["poly_100_1000_2"] = 0.9872486512996567
accuracy_scores["poly_1_100_3"] = 0.8754291319274154
accuracy_scores["poly_1_500_3"] = 0.9666503187837175
accuracy_scores["poly_1_1000_3"] = 0.9671407552721922
accuracy_scores["poly_10_100_3"] = 0.9774399215301618
accuracy_scores["poly_10_500_3"] = 0.984796468857283
accuracy_scores["poly_10_1000_3"] = 0.984796468857283
accuracy_scores["poly_100_100_3"] = 0.9813634134379597
accuracy_scores["poly_100_500_3"] = 0.9852869053457577
accuracy_scores["poly_100_1000_3"] = 0.9852869053457577

# %%
# linear graphs
values = [1,10,100]
iterations = [100,500,1000]
val_dict_linear = {}
for v in values:
    val_dict_linear[v] = []
iter_dict_linear = {}
for i in iterations:
    iter_dict_linear[i] = []
for v in values:
    for i in iterations:
        key = "linear_{}_{}".format(v,i)
        val_dict_linear[v].append(accuracy_scores[key])
        iter_dict_linear[i].append(accuracy_scores[key])

# %%
plt.figure(1)
for k in val_dict_linear:
  plt.plot(iterations, val_dict_linear[k], ls='-', marker='+')
plt.legend(val_dict_linear.keys(),title="C Values")
plt.xlabel("Iterations")
plt.ylabel("Accuracy")
plt.title("Linear: Iterations/Accuracy")
plt.figure(2)
for k in iter_dict_linear:
  plt.plot(values, iter_dict_linear[k], ls='-', marker='+')
plt.legend(iter_dict_linear.keys(),title="Iterations")
plt.xlabel("Values")
plt.ylabel("Accuracy")
plt.title("Linear: Values/Accuracy")
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
# rbf graphs
values = [1,10,100]
iterations = [100,500,1000]
val_dict_rbf = {}
for v in values:
    val_dict_rbf[v] = []
iter_dict_rbf = {}
for i in iterations:
    iter_dict_rbf[i] = []
for v in values:
    for i in iterations:
        key = "rbf_{}_{}".format(v,i)
        val_dict_rbf[v].append(accuracy_scores[key])
        iter_dict_rbf[i].append(accuracy_scores[key])

# %%
plt.figure(1)
for k in val_dict_rbf:
  plt.plot(iterations, val_dict_rbf[k], ls='-', marker='+')
plt.legend(val_dict_rbf.keys(),title="C Values")
plt.xlabel("Iterations")
plt.ylabel("Accuracy")
plt.title("RBF: Iterations/Accuracy")
plt.figure(2)
for k in iter_dict_rbf:
  plt.plot(values, iter_dict_rbf[k], ls='-', marker='+')
plt.legend(iter_dict_rbf.keys(),title="Iterations")
plt.xlabel("Values")
plt.ylabel("Accuracy")
plt.title("RBF: Values/Accuracy")
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
# sigmoid graphs
values = [1,10,100]
iterations = [100,500,1000]
val_dict_sigmoid = {}
for v in values:
    val_dict_sigmoid[v] = []
iter_dict_sigmoid = {}
for i in iterations:
    iter_dict_sigmoid[i] = []
for v in values:
    for i in iterations:
        key = "sigmoid_{}_{}".format(v,i)
        val_dict_sigmoid[v].append(accuracy_scores[key])
        iter_dict_sigmoid[i].append(accuracy_scores[key])

# %%
plt.figure(1)
for k in val_dict_sigmoid:
  plt.plot(iterations, val_dict_sigmoid[k], ls='-', marker='+')
plt.legend(val_dict_sigmoid.keys(),title="C Values")
plt.xlabel("Iterations")
plt.ylabel("Accuracy")
plt.title("Sigmoid: Iterations/Accuracy")
plt.figure(2)
for k in iter_dict_sigmoid:
  plt.plot(values, iter_dict_sigmoid[k], ls='-', marker='+')
plt.legend(iter_dict_sigmoid.keys(),title="Iterations")
plt.xlabel("Values")
plt.ylabel("Accuracy")
plt.title("Sigmoid: Values/Accuracy")
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
# poly degree 1 graphs
degree = 1
values = [1,10,100]
iterations = [100,500,1000]
val_dict_poly_1 = {}
for v in values:
    val_dict_poly_1[v] = []
iter_dict_poly_1 = {}
for i in iterations:
    iter_dict_poly_1[i] = []
for v in values:
    for i in iterations:
        key = "poly_{}_{}_{}".format(v,i,degree)
        val_dict_poly_1[v].append(accuracy_scores[key])
        iter_dict_poly_1[i].append(accuracy_scores[key])

# %%
# poly degree 2 graphs
degree = 2
values = [1,10,100]
iterations = [100,500,1000]
val_dict_poly_2 = {}
for v in values:
    val_dict_poly_2[v] = []
iter_dict_poly_2 = {}
for i in iterations:
    iter_dict_poly_2[i] = []
for v in values:
    for i in iterations:
        key = "poly_{}_{}_{}".format(v,i,degree)
        val_dict_poly_2[v].append(accuracy_scores[key])
        iter_dict_poly_2[i].append(accuracy_scores[key])

# %%
# poly degree 3 graphs
degree = 3
values = [1,10,100]
iterations = [100,500,1000]
val_dict_poly_3 = {}
for v in values:
    val_dict_poly_3[v] = []
iter_dict_poly_3 = {}
for i in iterations:
    iter_dict_poly_3[i] = []
for v in values:
    for i in iterations:
        key = "poly_{}_{}_{}".format(v,i,degree)
        val_dict_poly_3[v].append(accuracy_scores[key])
        iter_dict_poly_3[i].append(accuracy_scores[key])

# %%
plt.figure(1)
for k in val_dict_poly_1:
  plt.plot(iterations, val_dict_poly_1[k], ls='-', marker='+')
plt.legend(val_dict_poly_1.keys(),title="C Values")
plt.xlabel("Iterations")
plt.ylabel("Accuracy")
plt.title("Poly 1: Iterations/Accuracy")
plt.figure(2)
for k in iter_dict_poly_1:
  plt.plot(values, iter_dict_poly_1[k], ls='-', marker='+')
plt.legend(iter_dict_poly_1.keys(),title="Iterations")
plt.xlabel("Values")
plt.ylabel("Accuracy")
plt.title("Poly 1: Values/Accuracy")
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
plt.figure(1)
for k in val_dict_poly_2:
  plt.plot(iterations, val_dict_poly_2[k], ls='-', marker='+')
plt.legend(val_dict_poly_2.keys(),title="C Values")
plt.xlabel("Iterations")
plt.ylabel("Accuracy")
plt.title("Poly 2: Iterations/Accuracy")
plt.figure(2)
for k in iter_dict_poly_2:
  plt.plot(values, iter_dict_poly_2[k], ls='-', marker='+')
plt.legend(iter_dict_poly_2.keys(),title="Iterations")
plt.xlabel("Values")
plt.ylabel("Accuracy")
plt.title("Poly 2: Values/Accuracy")
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
plt.figure(1)
for k in val_dict_poly_3:
  plt.plot(iterations, val_dict_poly_3[k], ls='-', marker='+')
plt.legend(val_dict_poly_3.keys(),title="C Values")
plt.xlabel("Iterations")
plt.ylabel("Accuracy")
plt.title("Poly 3: Iterations/Accuracy")
plt.figure(2)
for k in iter_dict_poly_3:
  plt.plot(values, iter_dict_poly_3[k], ls='-', marker='+')
plt.legend(iter_dict_poly_3.keys(),title="Iterations")
plt.xlabel("Values")
plt.ylabel("Accuracy")
plt.title("Poly 3: Values/Accuracy")
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
for k in val_dict_sigmoid:
    print("Val: {}, {}".format(k, val_dict_sigmoid[k]))
for k in iter_dict_sigmoid:
    print("Iter: {}, {}".format(k, iter_dict_sigmoid[k]))
# Out:
# Val: 1, [0.5522314860225601, 0.7425208435507602, 0.7415399705738107]
# Val: 10, [0.5434036292300147, 0.6758214811181952, 0.6787641000490436]
# Val: 100, [0.5453653751839137, 0.6738597351642962, 0.6728788621873467]
# Iter: 100, [0.5522314860225601, 0.5434036292300147, 0.5453653751839137]
# Iter: 500, [0.7425208435507602, 0.6758214811181952, 0.6738597351642962]
# Iter: 1000, [0.7415399705738107, 0.6787641000490436, 0.6728788621873467]
